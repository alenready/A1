# %% [markdown]
# <a href="https://colab.research.google.com/github/alenready/A1/blob/main/MLAI_Sep24_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('/content/Iris (1).xlsx')

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             100 non-null    int64
#  1   SepalLengthCm  100 non-null    float64
#  2   SepalWidthCm   100 non-null    float64
#  3   PetalLengthCm  100 non-null    float64
#  4   PetalWidthCm   100 non-null    float64
#  5   Species        100 non-null    int64
# dtypes: float64(4), int64(2)
# memory usage: 4.8 KB

# %%
data.Species.value_counts()
# Out:
# Species
# 0    50
# 1    50
# Name: count, dtype: int64

# %%
data.drop('Id',axis=1,inplace = True)

# %%
x = data.drop('Species',axis = 1)
y = data['Species']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 55            5.7           2.8            4.5           1.3
# 88            5.6           3.0            4.1           1.3
# 26            5.0           3.4            1.6           0.4
# 42            4.4           3.2            1.3           0.2
# 69            5.6           2.5            3.9           1.1
# ..            ...           ...            ...           ...
# 60            5.0           2.0            3.5           1.0
# 71            6.1           2.8            4.0           1.3
# 14            5.8           4.0            1.2           0.2
# 92            5.8           2.6            4.0           1.2
# 51            6.4           3.2            4.5           1.5
#
# [80 rows x 4 columns]

# %%
y_train
# Out:
# 55    1
# 88    1
# 26    0
# 42    0
# 69    1
#      ..
# 60    1
# 71    1
# 14    0
# 92    1
# 51    1
# Name: Species, Length: 80, dtype: int64

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss = 'binary_crossentropy',optimizer = 'adam', metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5047 - loss: 0.9779
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5555 - loss: 0.8807
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5047 - loss: 0.9406
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5086 - loss: 0.9274
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5516 - loss: 0.8430
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5281 - loss: 0.8691
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5203 - loss: 0.8725
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5516 - loss: 0.8087
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5437 - loss: 0.8105
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5359 - loss: 0.8132
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5125 - loss: 0.8281
# Epoch 12/100
# ...

# %%
y_pred = model.predict(x_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %%
y_pred
# Out:
# array([[0.81689686],
#        [0.7319662 ],
#        [0.81253386],
#        [0.40822247],
#        [0.4544614 ],
#        [0.39588356],
#        [0.3994553 ],
#        [0.6981335 ],
#        [0.38442093],
#        [0.38595888],
#        [0.40286627],
#        [0.4172306 ],
#        [0.75946486],
#        [0.3849294 ],
#        [0.7539298 ],
#        [0.38912097],
#        [0.7634021 ],
#        [0.8006406 ],
#        [0.38805056],
#        [0.40551832]], dtype=float32)

# %%
y_pred[y_pred>0.5]=1
y_pred[y_pred<=0.5]=0

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
x = np.array([[5.1,3.5,1.4,0.2]])

# %%
pred = model.predict(x)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step

# %%
pred
# Out:
# array([[0.11454792]], dtype=float32)
