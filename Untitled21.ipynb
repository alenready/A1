# %% [markdown]
# <a href="https://colab.research.google.com/github/alenready/A1/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/beer-servings.csv')
df
# Out:
#      Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0             0  Afghanistan            0.0              0.0            0.0
# 1             1      Albania           89.0            132.0           54.0
# 2             2      Algeria           25.0              0.0           14.0
# 3             3      Andorra          245.0            138.0          312.0
# 4             4       Angola          217.0             57.0           45.0
# ..          ...          ...            ...              ...            ...
# 188         188    Venezuela            NaN            100.0            3.0
# 189         189      Vietnam          111.0              2.0            1.0
# 190         190        Yemen            6.0              0.0            0.0
# 191         191       Zambia           32.0             19.0            4.0
# 192         192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# ...

# %%
df.shape
# Out:
# (193, 7)

# %%
df.describe()
# Out:
#        Unnamed: 0  beer_servings  spirit_servings  wine_servings  \
# count  193.000000     185.000000       185.000000     187.000000
# mean    96.000000     105.124324        83.221622      50.165775
# std     55.858452     100.524714        89.142958      80.358868
# min      0.000000       0.000000         0.000000       0.000000
# 25%     48.000000      20.000000         4.000000       1.000000
# 50%     96.000000      76.000000        60.000000       9.000000
# 75%    144.000000     185.000000       132.000000      60.500000
# max    192.000000     376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    192.000000
# mean                       4.741667
# std                        3.767654
# min                        0.000000
# 25%                        1.300000
# 50%                        4.250000
# 75%                        7.200000
# max                       14.400000

# %%
# prompt: check null values

df.isnull().sum()
# Out:
# Unnamed: 0                      0
# country                         0
# beer_servings                   8
# spirit_servings                 8
# wine_servings                   6
# total_litres_of_pure_alcohol    1
# continent                       0
# dtype: int64

# %%
# prompt: fill null values

#df['beer_servings'].fillna(df['beer_servings'].mean(), inplace=True)
#df['wine_servings'].fillna(df['wine_servings'].mean(), inplace=True)
#df['spirit_servings'].fillna(df['spirit_servings'].mean(), inplace=True)
#df['total_litres_of_pure_alcohol'].fillna(df['total_litres_of_pure_alcohol'].mean(), inplace=True)
#df.isnull().sum()

# %% [markdown]
# # ***IQR METHOD HANDLING OUTLIERS***

# %%
Q1=df.total_litres_of_pure_alcohol.quantile(0.25)
Q3=df.total_litres_of_pure_alcohol.quantile(.75)
Q1,Q3
# Out:
# (1.3, 7.2)

# %%
IQR=Q3-Q1
IQR
# Out:
# 5.9

# %%
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
lower_limit,upper_limit
# Out:
# (-7.550000000000002, 16.05)

# %%
# prompt: boxplot

import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(df['total_litres_of_pure_alcohol'])
plt.show()

# %%
# prompt: plot outliers

import matplotlib.pyplot as plt

plt.figure()
plt.scatter(df['total_litres_of_pure_alcohol'], df['beer_servings'])
plt.xlabel('total_litres_of_pure_alcohol')
plt.ylabel('beer_servings')

# Plot the outlier points
plt.scatter(df[df['total_litres_of_pure_alcohol'] < lower_limit]['total_litres_of_pure_alcohol'], df[df['total_litres_of_pure_alcohol'] < lower_limit]['beer_servings'], c='red')
plt.scatter(df[df['total_litres_of_pure_alcohol'] > upper_limit]['total_litres_of_pure_alcohol'], df[df['total_litres_of_pure_alcohol'] > upper_limit]['beer_servings'], c='red')

plt.show()

# %%
# prompt: plot outliers in total_litres_of_pure_alcohol

import matplotlib.pyplot as plt

# Create a boxplot of the total_litres_of_pure_alcohol column
plt.boxplot(df['total_litres_of_pure_alcohol'])

# Add a title and labels to the plot
plt.title('Boxplot of Total Litres of Pure Alcohol')
plt.xlabel('Total Litres of Pure Alcohol')
plt.ylabel('Value')

# Show the plot
plt.show()

# %%
# prompt: Identify the outlier rows using the lower and upper limits.

outlier_rows = df[(df['total_litres_of_pure_alcohol'] < lower_limit) | (df['total_litres_of_pure_alcohol'] > upper_limit)]
print(outlier_rows)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, country, beer_servings, spirit_servings, wine_servings, total_litres_of_pure_alcohol, continent]
# Index: []

# %%
# prompt: Remove the outlier rows from the DataFrame.

df_without_outliers = df[(df['total_litres_of_pure_alcohol'] >= lower_limit) & (df['total_litres_of_pure_alcohol'] <= upper_limit)]

print(df_without_outliers)
# Out:
#      Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0             0  Afghanistan            0.0              0.0            0.0
# 1             1      Albania           89.0            132.0           54.0
# 2             2      Algeria           25.0              0.0           14.0
# 3             3      Andorra          245.0            138.0          312.0
# 4             4       Angola          217.0             57.0           45.0
# ..          ...          ...            ...              ...            ...
# 188         188    Venezuela            NaN            100.0            3.0
# 189         189      Vietnam          111.0              2.0            1.0
# 190         190        Yemen            6.0              0.0            0.0
# 191         191       Zambia           32.0             19.0            4.0
# 192         192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# ...

# %%
# prompt: Print the outlier rows and the DataFrame without outliers.

# Print the outlier rows
print("Outlier rows:")
print(outlier_rows)

# Print the DataFrame without outliers
print("\nDataFrame without outliers:")
print(df_without_outliers)
# Out:
# Outlier rows:
# Empty DataFrame
# Columns: [Unnamed: 0, country, beer_servings, spirit_servings, wine_servings, total_litres_of_pure_alcohol, continent]
# Index: []
#
# DataFrame without outliers:
#      Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0             0  Afghanistan            0.0              0.0            0.0
# 1             1      Albania           89.0            132.0           54.0
# 2             2      Algeria           25.0              0.0           14.0
# 3             3      Andorra          245.0            138.0          312.0
# 4             4       Angola          217.0             57.0           45.0
# ..          ...          ...            ...              ...            ...
# 188         188    Venezuela            NaN            100.0            3.0
# 189         189      Vietnam          111.0              2.0            1.0
# 190         190        Yemen            6.0              0.0            0.0
# ...

# %%
# prompt: show the  columns data

df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'beer_servings', 'spirit_servings',
#        'wine_servings', 'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %% [markdown]
# # ***z-score handling outliers***

# %%
# prompt: zscore on df

zscore = (df['total_litres_of_pure_alcohol'] - df['total_litres_of_pure_alcohol'].mean()) / df['total_litres_of_pure_alcohol'].std()

df['zscore'] = zscore

df.head()
# Out:
#    Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0           0  Afghanistan            0.0              0.0            0.0
# 1           1      Albania           89.0            132.0           54.0
# 2           2      Algeria           25.0              0.0           14.0
# 3           3      Andorra          245.0            138.0          312.0
# 4           4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol continent    zscore
# 0                           0.0      Asia -1.258520
# 1                           4.9    Europe  0.042024
# 2                           0.7    Africa -1.072728
# 3                          12.4    Europe  2.032653
# 4                           5.9    Africa  0.307442

# %%
#  zscore

zscore = (df['total_litres_of_pure_alcohol'] - df['total_litres_of_pure_alcohol'].mean()) / df['total_litres_of_pure_alcohol'].std()
zscore
# Out:
# 0     -1.258520
# 1      0.042024
# 2     -1.072728
# 3      2.032653
# 4      0.307442
#          ...
# 188    0.785192
# 189   -0.727685
# 190   -1.231978
# 191   -0.594977
# 192   -0.011059
# Name: total_litres_of_pure_alcohol, Length: 193, dtype: float64

# %%
# prompt: set the threshold for outlier detection

threshold = 3

# %%
# prompt: # Identify outlier rows based on the z-score

outlier_rows = df[abs(zscore) > 3]

# Print the outlier rows
print("Outlier rows:")
print(outlier_rows)
# Out:
# Outlier rows:
# Empty DataFrame
# Columns: [Unnamed: 0, country, beer_servings, spirit_servings, wine_servings, total_litres_of_pure_alcohol, continent, zscore]
# Index: []

# %%
# prompt: plot z score

import matplotlib.pyplot as plt
import seaborn as sns

# Create a boxplot of the z-scores
plt.figure()
sns.boxplot(df['zscore'])

# Add a title and labels to the plot
plt.title('Boxplot of Z-Scores')
plt.xlabel('Z-Score')
plt.ylabel('Value')

# Show the plot
plt.show()
