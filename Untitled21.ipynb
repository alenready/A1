# %% [markdown]
# <a href="https://colab.research.google.com/github/alenready/A1/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/beer-servings.csv')
df
# Out:
#      Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0             0  Afghanistan            0.0              0.0            0.0
# 1             1      Albania           89.0            132.0           54.0
# 2             2      Algeria           25.0              0.0           14.0
# 3             3      Andorra          245.0            138.0          312.0
# 4             4       Angola          217.0             57.0           45.0
# ..          ...          ...            ...              ...            ...
# 188         188    Venezuela            NaN            100.0            3.0
# 189         189      Vietnam          111.0              2.0            1.0
# 190         190        Yemen            6.0              0.0            0.0
# 191         191       Zambia           32.0             19.0            4.0
# 192         192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# 2                             0.7         Africa
# 3                            12.4         Europe
# 4                             5.9         Africa
# ..                            ...            ...
# 188                           7.7  South America
# 189                           2.0           Asia
# 190                           0.1           Asia
# 191                           2.5         Africa
# 192                           4.7         Africa
#
# [193 rows x 7 columns]

# %%
df.shape
# Out:
# (193, 7)

# %%
df.describe()
# Out:
#        Unnamed: 0  beer_servings  spirit_servings  wine_servings  \
# count  193.000000     185.000000       185.000000     187.000000
# mean    96.000000     105.124324        83.221622      50.165775
# std     55.858452     100.524714        89.142958      80.358868
# min      0.000000       0.000000         0.000000       0.000000
# 25%     48.000000      20.000000         4.000000       1.000000
# 50%     96.000000      76.000000        60.000000       9.000000
# 75%    144.000000     185.000000       132.000000      60.500000
# max    192.000000     376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    192.000000
# mean                       4.741667
# std                        3.767654
# min                        0.000000
# 25%                        1.300000
# 50%                        4.250000
# 75%                        7.200000
# max                       14.400000

# %%
Q1=df.total_litres_of_pure_alcohol.quantile(0.25)
Q3=df.total_litres_of_pure_alcohol.quantile(.75)
Q1,Q3
# Out:
# (1.3, 7.2)

# %%
IQR=Q3-Q1
IQR
# Out:
# 5.9

# %%
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
lower_limit,upper_limit
# Out:
# (-7.550000000000002, 16.05)

# %%
outliers=df[(df.total_litres_of_pure_alcohol<lower_limit)|(df.total_litres_of_pure_alcohol>upper_limit)]
outliers
#df[(df.total_litres_of_pure_alcohol<lower_limit)&(df.total_litres_of_pure_alcohol>upper_limit)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, country, beer_servings, spirit_servings, wine_servings, total_litres_of_pure_alcohol, continent, zscore]
# Index: []

# %%
df_non_outlier=df[(df.total_litres_of_pure_alcohol>lower_limit)|(df.total_litres_of_pure_alcohol<upper_limit)]
df_non_outlier
# Out:
#      Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0             0  Afghanistan            0.0              0.0            0.0
# 1             1      Albania           89.0            132.0           54.0
# 2             2      Algeria           25.0              0.0           14.0
# 3             3      Andorra          245.0            138.0          312.0
# 4             4       Angola          217.0             57.0           45.0
# ..          ...          ...            ...              ...            ...
# 188         188    Venezuela            NaN            100.0            3.0
# 189         189      Vietnam          111.0              2.0            1.0
# 190         190        Yemen            6.0              0.0            0.0
# 191         191       Zambia           32.0             19.0            4.0
# 192         192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent    zscore
# 0                             0.0           Asia -1.258520
# 1                             4.9         Europe  0.042024
# 2                             0.7         Africa -1.072728
# 3                            12.4         Europe  2.032653
# 4                             5.9         Africa  0.307442
# ..                            ...            ...       ...
# 188                           7.7  South America  0.785192
# 189                           2.0           Asia -0.727685
# 190                           0.1           Asia -1.231978
# 191                           2.5         Africa -0.594977
# 192                           4.7         Africa -0.011059
#
# [192 rows x 8 columns]

# %%
#  zscore

zscore = (df['total_litres_of_pure_alcohol'] - df['total_litres_of_pure_alcohol'].mean()) / df['total_litres_of_pure_alcohol'].std()
zscore
# Out:
# 0     -1.258520
# 1      0.042024
# 2     -1.072728
# 3      2.032653
# 4      0.307442
#          ...
# 188    0.785192
# 189   -0.727685
# 190   -1.231978
# 191   -0.594977
# 192   -0.011059
# Name: total_litres_of_pure_alcohol, Length: 193, dtype: float64

# %%
# prompt: IQR METHOD

Q1 = df['total_litres_of_pure_alcohol'].quantile(0.25)
Q3 = df['total_litres_of_pure_alcohol'].quantile(0.75)
IQR = Q3 - Q1
lower_limit = Q1 - (1.5 * IQR)
upper_limit = Q3 + (1.5 * IQR)
outliers = df[(df['total_litres_of_pure_alcohol'] < -7.550000000000002) | (df['total_litres_of_pure_alcohol'] > 16.05)]
print(outliers)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, country, beer_servings, spirit_servings, wine_servings, total_litres_of_pure_alcohol, continent, zscore]
# Index: []
