# %%
# ASSIGNMENT 1
! pip install pandas
# !pip install xlrd
import xlrd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_excel('iris.xlsx')
df
# Out:
# ...
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# 2. Display the columns in dataset
df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
#3.Calculate the mean of each column of dataset
df.mean(axis=0)
# Out:
# <ipython-input-11-d62ef4bfff11>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean(axis=0)
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
#4.Check for the null values in data set
df.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
#5. Meaningful three visualization using data set
import matplotlib.pyplot as plt
data=df.values
plt.scatter(data[:,0],data[:,1])
plt.xlabel("x axis- SL")
plt.ylabel("Y axis- SW")
plt.title("Scatter plot")
plt.show()

# %%
import seaborn as sns
df=pd.DataFrame([data[:,2]])
df.plot(kind="box")
#df=pd.DataFrame
#sns.barplot(data=df,x="x",y="y")
#data[0:100]
#data[1:100]
#data[2:100]
# Out:
# <Axes: >
